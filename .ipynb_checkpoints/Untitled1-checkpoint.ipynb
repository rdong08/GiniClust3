# %%
import scanpy as sc
#Set scipy version to 1.7.3; versuib 1.8.0 did not work 
# Suggestion: https://stackoverflow.com/questions/71106940/cannot-import-name-centered-from-scipy-signal-signaltools
import numpy as np
import giniclust3 as gc
import anndata

# %%
####Load and filter dataset####
adataRaw=sc.read_csv("/Users/adrianasistig/Documents/GitHub/GiniClust3/example/ESC/data/GSM1599495_ES_d0_biorep_techrep1.csv.gz",first_column_names=True)
#adataRaw=sc.read_csv("./data/GSM1599495_ES_d0_biorep_techrep1.csv",first_column_names=True)
sc.pp.filter_cells(adataRaw,min_genes=3)#####remover gene expressed less than N cell
sc.pp.filter_genes(adataRaw,min_cells=200)#####remove cell express less than M gene
adataSC=anndata.AnnData(X=adataRaw.X.T,obs=adataRaw.var,var=adataRaw.obs)
sc.pp.normalize_per_cell(adataSC, counts_per_cell_after=1e4)

# %%
####GiniIndexClust and FanoFactorClust####
gc.gini.calGini(adataSC)
adataGini=gc.gini.clusterGini(adataSC,neighbors=3)
# Out:
# Gene number is 23980
# Cell number is 2509

# %%
gc.fano.calFano(adataSC)
adataFano=gc.fano.clusterFano(adataSC)

# %%
####ConsensusClust####
consensusCluster={}
consensusCluster['giniCluster']=np.array(adataSC.obs['rare'].values.tolist())
consensusCluster['fanoCluster']=np.array(adataSC.obs['fano'].values.tolist())
gc.consensus.generateMtilde(consensusCluster)
gc.consensus.clusterMtilde(consensusCluster)
np.savetxt("final.txt",consensusCluster['finalCluster'], delimiter="\t",fmt='%s')

# %%
####UMAP visualization####
adataGini.obs['final']=consensusCluster['finalCluster']
adataFano.obs['final']=consensusCluster['finalCluster']
#gc.plot.umapGini(adataGini) #ERROR
#gc.plot.umapFano(adataFano) #ERROR
gc.plot.plotGini(adataGini)
gc.plot.plotFano(adataFano)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-4004aa1dc2f0> in <module>
#       2 adataGini.obs['final']=consensusCluster['finalCluster']
#       3 adataFano.obs['final']=consensusCluster['finalCluster']
# ----> 4 gc.plot.umapGini(adataGini)
#       5 gc.plot.umapFano(adataFano)
#
# AttributeError: module 'giniclust3.plot' has no attribute 'umapGini'

# %% [raw]
# # Error message
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-4004aa1dc2f0> in <module>
#       2 adataGini.obs['final']=consensusCluster['finalCluster']
#       3 adataFano.obs['final']=consensusCluster['finalCluster']
# ----> 4 gc.plot.umapGini(adataGini)
#       5 gc.plot.umapFano(adataFano)
#
# AttributeError: module 'giniclust3.plot' has no attribute 'umapGini'

# %%
gc.plot.plotGini(adataGini)
# Out:
# ... storing 'final' as categorical
# WARNING: saving figure to file figures/umap_finalCluster_umap_gini.pdf

# %%
gc.plot.plotFano(adataFano)
# Out:
# ... storing 'rare' as categorical
# ... storing 'final' as categorical
# WARNING: saving figure to file figures/umap_finalCluster_umap_fano.pdf
